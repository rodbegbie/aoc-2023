        for y in range(min(y1,y2), max(y1,y2)+1):
            for z in range(min(z1,z2), max(z1,z2)+1):
                yield [x,y,z]

for row in rows:
    brick1, brick2 = row.split('~')
    brick1 = list(map(int, brick1.split(',')))
    brick2 = list(map(int, brick2.split(',')))
    min_z = min(brick1[2], brick2[2])
    bricks.append([min_z, brick1, brick2])


while True:
    bricks.sort()
    # print (bricks)

    new_bricks = []

    grid = defaultdict(lambda: defaultdict(lambda: defaultdict(bool)))

    for (minz, brick1, brick2) in bricks:
        for (x,y,z) in get_brick_range(brick1, brick2):
            grid[x][y][z] = True
    
    # print(grid)

    dropped = False
    for (minz, brick1, brick2) in bricks:
        if minz == 1:
            # print ("LEVEL 1", brick1, brick2)
            new_bricks.append((minz, brick1, brick2))
            continue

        can_drop = True
        for (x,y,z) in get_brick_range(brick1, brick2):
            if grid[x][y][minz-1]:
                # print ("CAN'T DROP", brick1, brick2, grid[x][y][minz-1])
                can_drop = False
                break
        
        if can_drop:
            # print ("DROPPING", brick1, brick2)
            brick1[2] -= 1
            brick2[2] -= 1
            minz -= 1
            dropped = True

        new_bricks.append((minz, brick1, brick2))
    
    if not dropped:
        break
    
    bricks = new_bricks


dep_grid = defaultdict(lambda: defaultdict(lambda: defaultdict(set)))
bricks.sort()

grid = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: -1)))
deps = defaultdict(set)

for i in range(len(bricks)):
    (minz, brick1, brick2) = bricks[i]
    for (x,y,z) in get_brick_range(brick1, brick2):
        grid[x][y][z] = i

for i in range(len(bricks)):
    (minz, brick1, brick2) = bricks[i]
    for (x,y,z) in get_brick_range(brick1, brick2):
        if grid[x][y][minz-1] != -1:
            deps[i].add(grid[x][y][minz-1])

# print (deps)
can_disintegrate = set(range(len(bricks)))
for i in range(len(bricks)):
    dep = deps[i]
    if len(dep) == 1:
        can_disintegrate.discard(dep.pop())


print("CAN DISINTEGRATE", len(can_disintegrate))
# Out:
# CAN DISINTEGRATE 424

# %%
# Part 2

from collections import defaultdict

rows = INPUT.splitlines()
bricks = []

def get_brick_range(brick1, brick2):
    x1,y1,z1 = brick1
    x2,y2,z2 = brick2

    for x in range(min(x1,x2), max(x1,x2)+1):
        for y in range(min(y1,y2), max(y1,y2)+1):
            for z in range(min(z1,z2), max(z1,z2)+1):
                yield [x,y,z]

for row in rows:
    brick1, brick2 = row.split('~')
    brick1 = list(map(int, brick1.split(',')))
    brick2 = list(map(int, brick2.split(',')))
    min_z = min(brick1[2], brick2[2])
    bricks.append([min_z, brick1, brick2])


while True:
    bricks.sort()
    # print (bricks)

    new_bricks = []

    grid = defaultdict(lambda: defaultdict(lambda: defaultdict(bool)))

    for (minz, brick1, brick2) in bricks:
        for (x,y,z) in get_brick_range(brick1, brick2):
            grid[x][y][z] = True
    
    # print(grid)

    dropped = False
    for (minz, brick1, brick2) in bricks:
        if minz == 1:
            # print ("LEVEL 1", brick1, brick2)
            new_bricks.append((minz, brick1, brick2))
            continue

        can_drop = True
        for (x,y,z) in get_brick_range(brick1, brick2):
            if grid[x][y][minz-1]:
                # print ("CAN'T DROP", brick1, brick2, grid[x][y][minz-1])
                can_drop = False
                break
        
        if can_drop:
            # print ("DROPPING", brick1, brick2)
            brick1[2] -= 1
            brick2[2] -= 1
            minz -= 1
            dropped = True

        new_bricks.append((minz, brick1, brick2))
    
    if not dropped:
        break
    
    bricks = new_bricks


dep_grid = defaultdict(lambda: defaultdict(lambda: defaultdict(set)))
bricks.sort()

grid = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: -1)))
deps = defaultdict(set)

supports = defaultdict(set)
supported_by = defaultdict(set)

for i in range(len(bricks)):
    (minz, brick1, brick2) = bricks[i]
    for (x,y,z) in get_brick_range(brick1, brick2):
        grid[x][y][z] = i

for i in range(len(bricks)):
    (minz, brick1, brick2) = bricks[i]
    for (x,y,z) in get_brick_range(brick1, brick2):
        if grid[x][y][minz-1] != -1:
            deps[grid[x][y][minz-1]].add(i)
            supported_by[i].add(grid[x][y][minz-1])
            supports[grid[x][y][minz-1]].add(i)

# print (deps)

seen = set()
def fill_deps(j):
    # print ("FILLING", j)
    if j in seen:
        # print ("SEEN")
        return deps[j]
    seen.add(j)

    (minz, brick1, brick2) = bricks[j]
    if not deps[j]:
        # print ("NO DEPS")
        deps[j] = set()
        return deps[j]
    else:
        for i in list(deps[j]):
            # print ("i", i, "j", j, fill_deps(i))
            deps[j] |= fill_deps(i)
            return deps[j]

for i in range(len(bricks)):
    fill_deps(i)
    print (i, deps[i], supports[i], supported_by[i])

# print (deps)
count = 0
can_disintegrate = 0
for i in range(len(bricks)):
    will_fall = set()
    for j in supports[i]:
        if not supported_by[j] - {i}:
            print ("REMOVE", i, "FALL", j, len(deps[j]) + 1)
            will_fall.add(j)
            will_fall |= deps[j]
    count += len(will_fall)
    if not will_fall:
        can_disintegrate += 1

    

print ("CAN DISINTEGRATE", can_disintegrate, "WILL FALL", count)
# Out:
# 0 {15} {15} set()
# 1 {17} {17} set()
# 2 {16, 48, 18, 50, 36, 26, 92} {16, 18} set()
# 3 {70, 58, 60, 46} {46} set()
# 4 {19, 22, 39, 27, 28, 30} {19, 22} set()
# 5 set() set() set()
# 6 {32, 21, 40, 30, 31} {21} set()
# 7 {16, 48, 50, 36, 26, 92} {16} set()
# 8 {34, 20, 29} {20} set()
# 9 set() set() set()
# 10 set() set() set()
# 11 {69, 135, 138, 79, 150, 155, 91, 57, 101, 102, 166, 42, 112, 53, 54, 120, 121, 127} {42} set()
# 12 {23} {23} set()
# 13 {24} {24} set()
# 14 set() set() set()
# 15 set() set() {0}
# 16 {48, 50, 36, 26, 92} {26} {2, 7}
# 17 set() set() {1}
# 18 {25, 35, 61, 47} {25} {2}
# 19 {27, 28, 30, 39} {27, 28, 30} {4}
# 20 {34, 29} {34, 29} {8}
# 21 {32, 40, 30, 31} {32, 30, 31} {6}
# 22 {33, 68, 45, 55} {33} {4}
# 23 set() set() {12}
# 24 set() set() {13}
# 25 {35, 61, 47} {35} {18}
# 26 {48, 50, 36, 92} {36} {16}
# 27 {39} {39} {19}
# 28 {41, 39} {41, 39} {19}
# 29 set() set() {20}
# 30 {51, 37, 73, 75, 62} {37} {19, 21}
# ...
